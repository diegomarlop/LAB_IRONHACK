# %% [markdown]
# <a href="https://colab.research.google.com/github/diegomarlop/LAB_IRONHACK/blob/main/Lab8_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab | Web Scraping Single Page

# %%
import pandas as pd

# %%
import requests
from bs4 import BeautifulSoup
url = 'https://www.billboard.com/charts/hot-100/'
billboard_html = requests.get(url).content
soup = BeautifulSoup(billboard_html, "html.parser")
soup

# %% [markdown]
# Your product will take a song as an input from the user and will output another song (the recommendation). In most cases, the recommended song will have to be similar to the inputted song, but the CTO thinks that if the song is on the top charts at the moment, the user will enjoy more a recommendation of a song that's also popular at the moment.
#
# You have find data on the internet about currently popular songs. Billboard maintains a weekly Top 100 of "hot" songs here: https://www.billboard.com/charts/hot-100.
#
# It's a good place to start! Scrape the current top 100 songs and their respective artists, and put the information into a pandas dataframe.

# %%
song=[]
for songs in soup.find_all(class_='o-chart-results-list-row-container'):
  top = songs.find('h3').get_text(strip=True)
  song.append(top)

# %%
song
# Out:
# ['Flowers',
#  'Kill Bill',
#  "Creepin'",
#  "Boy's A Liar, Pt. 2",
#  'Last Night',
#  'Unholy',
#  'Die For You',
#  'Anti-Hero',
#  'Cuff It',
#  "I'm Good (Blue)",
#  'Just Wanna Rock',
#  'As It Was',
#  'Thank God',
#  'Rich Flex',
#  'Love You Anyway',
#  'Thought You Should Know',
#  'Under The Influence',
#  'Rock And A Hard Place',
#  'Golden Hour',
#  'Made You Look',
#  'Something In The Orange',
#  'Players',
#  'You Proof',
#  'Lavender Haze',
#  'Calm Down',
#  'Escapism',
#  'Going, Going, Gone',
#  'Bad Habit',
#  'Superhero (Heroes & Villains)',
#  'Shirt',
#  'Sure Thing',
#  'Until I Found You',
#  'Snooze',
#  'Heart Like A Truck',
#  'The Kind Of Love We Make',
#  'Wait For U',
#  'Umbrella',
#  'Lost',
#  'I Like You (A Happier Song)',
#  'Bzrp Music Sessions, Vol. 53',
#  'Lift Me Up',
#  'Bebe Dame',
#  'Wait In The Truck',
#  'Diamonds',
#  'Tomorrow 2',
#  'About Damn Time',
#  'She Had Me At Heads Carolina',
#  'We Found Love',
# ...

# %%
import re
artists=[]
for artist in soup.find_all(class_='o-chart-results-list-row-container'):
  top2 = artist.find('span').findNext('span').get_text(strip=True)
  artists.append(top2)

# %%
artists
# Out:
# ['Miley Cyrus',
#  'SZA',
#  'Metro Boomin, The Weeknd & 21 Savage',
#  'PinkPantheress & Ice Spice',
#  'Morgan Wallen',
#  'Sam Smith & Kim Petras',
#  'The Weeknd',
#  'Taylor Swift',
#  'Beyonce',
#  'David Guetta & Bebe Rexha',
#  'Lil Uzi Vert',
#  'Harry Styles',
#  'Kane Brown With Katelyn Brown',
#  'Drake & 21 Savage',
#  'NEW',
#  'Morgan Wallen',
#  'Chris Brown',
#  'Bailey Zimmerman',
#  'JVKE',
#  'Meghan Trainor',
#  'Zach Bryan',
#  'Coi Leray',
#  'Morgan Wallen',
#  'Taylor Swift',
#  'Rema & Selena Gomez',
#  'RAYE Featuring 070 Shake',
#  'Luke Combs',
#  'Steve Lacy',
#  'Metro Boomin, Future & Chris Brown',
#  'SZA',
#  'Miguel',
#  'Stephen Sanchez',
#  'SZA',
#  'Lainey Wilson',
#  'Luke Combs',
#  'Future Featuring Drake & Tems',
#  'RE-\nENTRY',
#  'NEW',
#  'Post Malone Featuring Doja Cat',
#  'Bizarrap & Shakira',
#  'Rihanna',
#  'Fuerza Regida X Grupo Frontera',
#  'HARDY Featuring Lainey Wilson',
#  'RE-\nENTRY',
#  'GloRilla & Cardi B',
#  'Lizzo',
# ...

# %%
import pandas as pd 
top_songs = pd.DataFrame(song,artists).reset_index()
top_songs.columns =['artist','song']

# %%
top_songs
# Out:
#                                          artist                 song
# 0                                   Miley Cyrus              Flowers
# 1                                           SZA            Kill Bill
# 2          Metro Boomin, The Weeknd & 21 Savage             Creepin'
# 3                    PinkPantheress & Ice Spice  Boy's A Liar, Pt. 2
# 4                                 Morgan Wallen           Last Night
# ..                                          ...                  ...
# 95                                 Jordan Davis  Next Thing You Know
# 96  Metro Boomin Featuring Don Toliver & Future      Too Many Nights
# 97                       Nengo Flow & Bad Bunny        Gato de Noche
# 98                                          NEW    Painting Pictures
# 99                                Morgan Wallen        Tennessee Fan
#
# [100 rows x 2 columns]
